# %% [markdown]
# # EzTao*X* binder instance
#
# Welcome to EzTaoX!
#
# Source code: https://github.com/LSST-AGN-Variability/EzTaoX
#
# RTD: https://eztaox.readthedocs.io/en/latest/index.html
#
# notebooks:
# - ../docs/notebooks/01_MultibandFitting.ipynb
# - [02_DHO](../docs/notebooks/02_DHO.ipynb)
